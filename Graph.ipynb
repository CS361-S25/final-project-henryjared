# %%
# Dependencies (Uncomment and run the following)
# pip install pandas
# pip install numpy
# pip install matplotlib

# go back into report
# gui webpage add text and flowers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pl1_gray_df = pd.read_csv("/Users/arroyoruizj/Desktop/ALDE_Work/final-project-henryjared/gray.csv")
pl1_gray_df = pl1_gray_df[(pl1_gray_df['t'] <= 605000)]

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Top plot: Proportion of Daisies
axs[0].plot(pl1_gray_df['L'], pl1_gray_df['a_g'], label='Gray Daisies', color='black', linestyle='dashdot')

axs[0].set_xlim([0, 2])
axs[0].set_ylim([0, 0.8])
axs[0].set_yticks([.2, .4, .6])
axs[0].legend(loc='upper center', ncols=2)
axs[0].set_ylabel("Area %", size=13)


axs[1].plot(pl1_gray_df['L'], pl1_gray_df['temp'], color='black')
axs[1].set_xlim([0, 2])
axs[1].set_ylim([0, 70])
axs[1].set_yticks([20, 40, 60])
axs[1].set_xlabel("Solar Luminosity", size=13)
axs[1].set_ylabel("Temperature (°C)", size=13)

plt.tight_layout()
plt.xlim([0.6, 1.7])
plt.show()

# %%
pl2_black_df = pd.read_csv("/Users/arroyoruizj/Desktop/ALDE_Work/final-project-henryjared/black.csv")
pl2_black_df = pl2_black_df[(pl2_black_df['t'] <= 605000)]

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Top plot: Proportion of Daisies
axs[0].plot(pl2_black_df['L'], pl2_black_df['a_b'], label='Black Daisies', color='black')

axs[0].set_xlim([0, 2])
axs[0].set_ylim([0, 0.8])
axs[0].set_yticks([.2, .4, .6])
axs[0].legend(loc='upper center', ncols=2)
axs[0].set_ylabel("Area %", size=13)


axs[1].plot(pl2_black_df['L'], pl2_black_df['temp'], color='black')
axs[1].set_xlim([0, 2])
axs[1].set_ylim([0, 70])
axs[1].set_yticks([20, 40, 60])
axs[1].set_xlabel("Solar Luminosity", size=13)
axs[1].set_ylabel("Temperature (°C)", size=13)

plt.tight_layout()
plt.xlim([0.6, 1.7])
plt.show()

# %%
pl3_white_df = pd.read_csv("/Users/arroyoruizj/Desktop/ALDE_Work/final-project-henryjared/white.csv")
pl3_white_df = pl3_white_df[(pl3_white_df['t'] <= 605000)]

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Top plot: Proportion of Daisies
axs[0].plot(pl3_white_df['L'], pl3_white_df['a_w'], label='White Daisies', color='black', linestyle=':')

axs[0].set_xlim([0, 2])
axs[0].set_ylim([0, 0.8])
axs[0].set_yticks([.2, .4, .6])
axs[0].legend(loc='upper center', ncols=2)
axs[0].set_ylabel("Area %", size=13)


axs[1].plot(pl3_white_df['L'], pl3_white_df['temp'], color='black')
axs[1].set_xlim([0, 2])
axs[1].set_ylim([0, 70])
axs[1].set_yticks([20, 40, 60])
axs[1].set_xlabel("Solar Luminosity", size=13)
axs[1].set_ylabel("Temperature (°C)", size=13)

plt.tight_layout()
plt.xlim([0.6, 1.7])
plt.show()

# %%
df = pd.read_csv("/Users/arroyoruizj/Desktop/ALDE_Work/final-project-henryjared/black_and_white.csv")
df = df[(df['t'] >= 50000) & (df['t'] <= 6050000)]

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Top plot: Proportion of Daisies
axs[0].plot(df['L'], df['a_b'], label='Black Daisies', color='black')
axs[0].plot(df['L'], df['a_w'], label='White Daisies', color='black', linestyle=':')

axs[0].set_xlim([0, 2])
axs[0].set_ylim([0, 0.8])
axs[0].set_yticks([.2, .4, .6])
axs[0].legend(loc='upper center', ncols=2)
axs[0].set_ylabel("Area %", size=13)


axs[1].plot(df['L'], df['temp'], color='black')
axs[1].set_xlim([0, 2])
axs[1].set_ylim([0, 70])
axs[1].set_yticks([20, 40, 60])
axs[1].set_xlabel("Solar Luminosity", size=13)
axs[1].set_ylabel("Temperature (°C)", size=13)


plt.tight_layout()
plt.xlim([0.6, 1.7])
plt.savefig("BWArea_Luminosity.png")
plt.show()

# %%
gray_df = pd.read_csv('/Users/arroyoruizj/Desktop/ALDE_Work/final-project-henryjared/white_black_and_gray.csv')
gray_df = gray_df[(gray_df['t'] >= 50000) & (gray_df['t'] <= 6050000)]

fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Top plot: Proportion of Daisies
axs[0].plot(gray_df['L'], gray_df['a_b'], label='Black Daisies', color='black')
axs[0].plot(gray_df['L'], gray_df['a_g'], label='Gray Daisies', color='black', linestyle='dashdot')
axs[0].plot(gray_df['L'], gray_df['a_w'], label='White Daisies', color='black', linestyle=':')


axs[0].set_xlim([0, 2])
axs[0].set_ylim([0, 0.8])
axs[0].set_yticks([.2, .4, .6])
axs[0].legend(loc='upper center', ncols=3)
axs[0].set_ylabel("Area %", size=13)


axs[1].plot(gray_df['L'], gray_df['temp'], color='black')
axs[1].set_xlim([0, 2])
axs[1].set_ylim([0, 70])
axs[1].set_yticks([20, 40, 60])
axs[1].set_xlabel("Solar Luminosity", size=13)
axs[1].set_ylabel("Temperature (°C)", size=13)


plt.tight_layout()
plt.xlim([0.6, 1.7])
plt.savefig("BWGArea_Luminosity.png")
plt.show()
#gray daisies make white daises die faster

# %%
plt.figure(figsize=(10, 8))

plt.plot(gray_df['L'], gray_df['temp'], color='red')
plt.plot(df['L'], df['temp'], color='black')
plt.xlim([0, 2])
plt.ylim([0, 70])
plt.yticks([20, 40, 60])
plt.xlabel("Solar Luminosity", size=13)
plt.ylabel("Temperature (°C)", size=13)

plt.show()
